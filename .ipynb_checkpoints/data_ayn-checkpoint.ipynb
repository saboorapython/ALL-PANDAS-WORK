# %%
import pandas as pd

# %%
df=pd.read_csv("data_any.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7   626   6
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     str
#  1   Span    62 non-null     str
#  2   Mat     62 non-null     int64
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     str
#  7   Ave     62 non-null     float64
#  8   BF      62 non-null     str
#  9   SR      62 non-null     str
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     str
#  13  4s      62 non-null     int64
#  14  6s      62 non-null     int64
# dtypes: float64(1), int64(8), str(6)
# memory usage: 7.4 KB

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='str')

# %%
df.rename(columns={'Mat':'matches', 'Inns':'innings', 'NO':'Not_Out', 'HS':'High_Score', 'Ave':'average', 'BF':'ball_faced', 'SR':'strike_rate'},inplace=True)

# %%
df
# Out:
#                Player       Span  matches  innings  Not_Out  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    PHKD Mendis (SL)  2022-2025       12       21        2  1184       182*
# 2      AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4     GA Headley (WI)  1930-1954       22       40        4  2190       270*
# ..                ...        ...      ...      ...      ...   ...        ...
# 57   KD Walters (AUS)  1965-1981       74      125       14  5357        250
# 58  GC Smith (ICC/SA)  2002-2014      117      205       13  9265        277
# 59  WH Ponsford (AUS)  1924-1934       29       48        4  2122        266
# 60    SJ McCabe (AUS)  1930-1938       39       62        5  2748        232
# 61   DR Jardine (ENG)  1928-1934       22       33        6  1296        127
#
# ...

# %%
df.sample(4)
# Out:
#                  Player       Span  matches  innings  Not_Out  Runs  \
# 18   GE Tyldesley (ENG)  1921-1929       14       20        2   990
# 57     KD Walters (AUS)  1965-1981       74      125       14  5357
# 55  TT Samaraweera (SL)  2001-2013       81      132       20  5462
# 5     H Sutcliffe (ENG)  1924-1935       54       84        9  4555
#
#    High_Score  average ball_faced strike_rate  100  50   0   4s  6s Country
# 18        122    55.00       178+       29.21    3   6   2   37   2     ENG
# 57        250    48.26      8662+       49.16   15  33   4  525  23     AUS
# 55        231    48.76      11641       46.92   14  30  11  633   7      SL
# 5         194    60.73      6558+       34.59   16  23   2  202   6     ENG

# %%
df['Player'].str.split(pat=")").str[0]
# Out:
# 0      DG Bradman (AUS
# 1      PHKD Mendis (SL
# 2        AC Voges (AUS
# 3       RG Pollock (SA
# 4       GA Headley (WI
#             ...
# 57     KD Walters (AUS
# 58    GC Smith (ICC/SA
# 59    WH Ponsford (AUS
# 60      SJ McCabe (AUS
# 61     DR Jardine (ENG
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df['Player'].str.split(pat="(").str[1] #split object m chalta h ur string m

# %%
df["Country"]=df["Country"].str.split(pat=")").str[0]

# %%
df
# Out:
#                Player       Span  matches  innings  Not_Out  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    PHKD Mendis (SL)  2022-2025       12       21        2  1184       182*
# 2      AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4     GA Headley (WI)  1930-1954       22       40        4  2190       270*
# ..                ...        ...      ...      ...      ...   ...        ...
# 57   KD Walters (AUS)  1965-1981       74      125       14  5357        250
# 58  GC Smith (ICC/SA)  2002-2014      117      205       13  9265        277
# 59  WH Ponsford (AUS)  1924-1934       29       48        4  2122        266
# 60    SJ McCabe (AUS)  1930-1938       39       62        5  2748        232
# 61   DR Jardine (ENG)  1928-1934       22       33        6  1296        127
#
# ...

# %%
df['Player'].str.split(pat="(").str[1] #split object m chalta h ur string m
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 57       AUS)
# 58    ICC/SA)
# 59       AUS)
# 60       AUS)
# 61       ENG)
# Name: Player, Length: 62, dtype: object

# %%
df
# Out:
#                Player       Span  matches  innings  Not_Out  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    PHKD Mendis (SL)  2022-2025       12       21        2  1184       182*
# 2      AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4     GA Headley (WI)  1930-1954       22       40        4  2190       270*
# ..                ...        ...      ...      ...      ...   ...        ...
# 57   KD Walters (AUS)  1965-1981       74      125       14  5357        250
# 58  GC Smith (ICC/SA)  2002-2014      117      205       13  9265        277
# 59  WH Ponsford (AUS)  1924-1934       29       48        4  2122        266
# 60    SJ McCabe (AUS)  1930-1938       39       62        5  2748        232
# 61   DR Jardine (ENG)  1928-1934       22       33        6  1296        127
#
# ...
