# %%
import pandas as pd

# %%
df=pd.read_csv("cricinfo - cricinfo.csv")

# %%
df["country"]=df["Player"].str.split(pat="(").str[1]

# %%
df["country"]=df["country"].str.split(pat="(").str[0]

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s  country
# ...

# %%
df["start_year"]=df["Span"].str.split(pat="_").str[0]
df["end_year"]=df["Span"].str.split(pat="_").str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s  country Start_year  end_year start_year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      62 non-null     object
#  1   Span        62 non-null     object
#  2   Mat         62 non-null     int64
#  3   Inns        62 non-null     int64
#  4   NO          62 non-null     int64
#  5   Runs        62 non-null     int64
#  6   HS          62 non-null     object
#  7   Ave         62 non-null     float64
#  8   BF          62 non-null     object
#  9   SR          62 non-null     object
#  10  100         62 non-null     int64
#  11  50          62 non-null     int64
#  12  0           62 non-null     object
#  13  4s          62 non-null     int64
#  14  6s          62 non-null     int64
#  15  country     62 non-null     object
#  16  Start_year  62 non-null     object
#  17  end_year    0 non-null      float64
#  18  start_year  62 non-null     object
# ...

# %%
df["start_year"]=df["start_year"].astype(int)
df["end_year"]=df["end_year"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df["start_year"]=df["start_year"].astype(int)
#       2 df["end_year"]=df["end_year"].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# ...

# %%
df

# %%
df["Player"]=df["Player"].str

# %%
df.sample(10)

# %%
df.groupby("country")["Mat"].sum()
# Out:
# country
# AUS)        1305
# ENG)         708
# ICC/IND)     268
# ICC/PAK)     120
# ICC/SA)      283
# ICC/WI)      131
# IND)         361
# NZ)          105
# PAK)         367
# SA)          234
# SL)          376
# WI)          558
# ZIM)          63
# Name: Mat, dtype: int64

# %%
df.groupby("country")["Mat"].sum().sort_values()
# Out:
# country
# ZIM)          63
# NZ)          105
# ICC/PAK)     120
# ICC/WI)      131
# SA)          234
# ICC/IND)     268
# ICC/SA)      283
# IND)         361
# PAK)         367
# SL)          376
# WI)          558
# ENG)         708
# AUS)        1305
# Name: Mat, dtype: int64

# %%
df.groupby("country")["Mat"].sum().sort_values(ascending=False)
# Out:
# country
# AUS)        1305
# ENG)         708
# WI)          558
# SL)          376
# PAK)         367
# IND)         361
# ICC/SA)      283
# ICC/IND)     268
# SA)          234
# ICC/WI)      131
# ICC/PAK)     120
# NZ)          105
# ZIM)          63
# Name: Mat, dtype: int64

# %%
df.groupby("country")["Mat"].sum().sort_values(ascending=False).reset_index()
# Out:
#      country   Mat
# 0       AUS)  1305
# 1       ENG)   708
# 2        WI)   558
# 3        SL)   376
# 4       PAK)   367
# 5       IND)   361
# 6    ICC/SA)   283
# 7   ICC/IND)   268
# 8        SA)   234
# 9    ICC/WI)   131
# 10  ICC/PAK)   120
# 11       NZ)   105
# 12      ZIM)    63

# %%
df12=df.groupby("country")["Mat"].sum().sort_values(ascending=False).reset_index()

# %%
df12.plot(kind="bar",x="country",y="Mat")
# Out:
# <Axes: xlabel='country'>

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s  country Start_year  end_year start_year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      62 non-null     object
#  1   Span        62 non-null     object
#  2   Mat         62 non-null     int64
#  3   Inns        62 non-null     int64
#  4   NO          62 non-null     int64
#  5   Runs        62 non-null     int64
#  6   HS          62 non-null     object
#  7   Ave         62 non-null     float64
#  8   BF          62 non-null     object
#  9   SR          62 non-null     object
#  10  100         62 non-null     int64
#  11  50          62 non-null     int64
#  12  0           62 non-null     object
#  13  4s          62 non-null     int64
#  14  6s          62 non-null     int64
#  15  country     62 non-null     object
#  16  Start_year  62 non-null     object
#  17  end_year    0 non-null      float64
#  18  start_year  62 non-null     object
# ...

# %%
df["HS"]=df["HS"].str.split(pat="*").str[0]
df["BF"]=df["BF"].str.split(pat="+").str[0]
#df["SR"]
#df["0"]

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs   HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996  334  99.94   9800
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256  274  60.97   1707
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270  60.83    416
# ..                ...        ...  ...   ...  ..   ...  ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357  250  48.26   8662
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265  277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122  266  48.22   3118
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748  232  48.21   3217
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296  127  48.00   2110
#
#        SR  100  50   0    4s  6s  country Start_year  end_year start_year
# ...

# %%
df["HS"]=df["HS"].astype(int)

# %%
df["HS"].astype(int)
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: HS, Length: 62, dtype: int64

# %%
df[df["BF"]=="-"]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs   HS    Ave BF SR  \
# 8         ED Weekes (WI)  1948-1958   48    81   5  4455  207  58.61  -  -
# 15       CL Walcott (WI)  1948-1960   44    74   7  3798  220  56.68  -  -
# 54  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144  48.79  -  -
#
#     100  50  0   4s  6s country Start_year  end_year start_year
# 8    15  19  6  258   2     WI)  1948-1958       NaN  1948-1958
# 15   15  14  1  107  11     WI)  1948-1960       NaN  1948-1960
# 54    5   6  3   51   0    ENG)  1893-1905       NaN  1893-1905
