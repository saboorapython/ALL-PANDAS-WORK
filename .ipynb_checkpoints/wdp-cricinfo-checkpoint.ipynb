# %%
import pandas as pd

# %%
df=pd.read_csv("cricinfo.csv")

# %%
df["country"]=df["Player"].str.split(pat="(").str[1]

# %%
df["country"]=df["country"].str.split(pat=")").str[0]

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s country
# ...

# %%
df["start_year"]=df["Span"].str.split(pat="-").str[0]
df["end_year"]=df["Span"].str.split(pat="-").str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s country start_year end_year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      62 non-null     object
#  1   Span        62 non-null     object
#  2   Mat         62 non-null     int64
#  3   Inns        62 non-null     int64
#  4   NO          62 non-null     int64
#  5   Runs        62 non-null     int64
#  6   HS          62 non-null     object
#  7   Ave         62 non-null     float64
#  8   BF          62 non-null     object
#  9   SR          62 non-null     object
#  10  100         62 non-null     int64
#  11  50          62 non-null     int64
#  12  0           62 non-null     object
#  13  4s          62 non-null     int64
#  14  6s          62 non-null     int64
#  15  country     62 non-null     object
#  16  start_year  62 non-null     object
#  17  end_year    62 non-null     object
# dtypes: float64(1), int64(8), object(9)
# ...

# %%
df["start_year"]=df["start_year"].astype(int)
df["end_year"]=df["end_year"].astype(int)

# %%
df["Span"]=df["end_year"]-df["start_year"]

# %%
# Out:
#                Player  Span  Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0    DG Bradman (AUS)    20   52    80  10  6996   334  99.94  9800+   58.6
# 1    PHKD Mendis (SL)     3   12    21   2  1184  182*  62.31   1839  64.38
# 2      AC Voges (AUS)     1   20    31   7  1485  269*  61.87   2667  55.68
# 3     RG Pollock (SA)     7   23    41   4  2256   274  60.97  1707+  54.48
# 4     GA Headley (WI)    24   22    40   4  2190  270*  60.83   416+     56
# ..                ...   ...  ...   ...  ..   ...   ...    ...    ...    ...
# 57   KD Walters (AUS)    16   74   125  14  5357   250  48.26  8662+  49.16
# 58  GC Smith (ICC/SA)    12  117   205  13  9265   277  48.25  15525  59.67
# 59  WH Ponsford (AUS)    10   29    48   4  2122   266  48.22  3118+  44.77
# 60    SJ McCabe (AUS)     8   39    62   5  2748   232  48.21  3217+  60.02
# 61   DR Jardine (ENG)     6   22    33   6  1296   127  48.00  2110+  25.59
#
#     100  50   0    4s  6s country  start_year  end_year
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s', 'country', 'start_year', 'end_year'],
#       dtype='object')

# %%
df.rename(columns={'Span':"Duration"},inplace=True)

# %%
df
# Out:
#                Player  Duration  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)        20   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)         3   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)         1   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)         7   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)        24   22    40   4  2190  270*  60.83   416+
# ..                ...       ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)        16   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)        12  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)        10   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)         8   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)         6   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s country  start_year  end_year
# ...

# %%
df["Player"]=df["Player"].str.split(pat="(").str[0]

# %%
#country wise number of  matches

# %%
df.sample(10)
# Out:
#            Player  Duration  Mat  Inns  NO   Runs    HS    Ave      BF     SR  \
# 20      CA Davis          5   15    29   5   1301   183  54.20    665+  35.48
# 48       CP Mead         17   17    26   2   1185  182*  49.37    619+  30.04
# 49      V Sehwag         12  104   180   6   8586   319  49.34   10441  82.23
# 8      ED Weekes         10   48    81   5   4455   207  58.61       -      -
# 1    PHKD Mendis          3   12    21   2   1184  182*  62.31    1839  64.38
# 61    DR Jardine          6   22    33   6   1296   127  48.00   2110+  25.59
# 36   SM Gavaskar         16  125   214  16  10122  236*  51.12  14184+  43.35
# 24  SR Tendulkar         24  200   329  33  15921  248*  53.78  29437+  54.04
# 30   Younis Khan         17  118   213  19  10099   313  52.05   19375  52.12
# 16      L Hutton         18   79   138  15   6971   364  56.67   2844+  39.34
#
#     100  50   0    4s  6s  country  start_year  end_year
# ...

# %%
df12=df.groupby("country")["Mat"].sum().sort_values(ascending=False).reset_index()

# %%
df12.plot(kind="bar",x="country",y="Mat")
# Out:
# <Axes: xlabel='country'>

# %%
df
# Out:
#           Player  Duration  Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0    DG Bradman         20   52    80  10  6996   334  99.94  9800+   58.6
# 1   PHKD Mendis          3   12    21   2  1184  182*  62.31   1839  64.38
# 2      AC Voges          1   20    31   7  1485  269*  61.87   2667  55.68
# 3    RG Pollock          7   23    41   4  2256   274  60.97  1707+  54.48
# 4    GA Headley         24   22    40   4  2190  270*  60.83   416+     56
# ..           ...       ...  ...   ...  ..   ...   ...    ...    ...    ...
# 57   KD Walters         16   74   125  14  5357   250  48.26  8662+  49.16
# 58     GC Smith         12  117   205  13  9265   277  48.25  15525  59.67
# 59  WH Ponsford         10   29    48   4  2122   266  48.22  3118+  44.77
# 60    SJ McCabe          8   39    62   5  2748   232  48.21  3217+  60.02
# 61   DR Jardine          6   22    33   6  1296   127  48.00  2110+  25.59
#
#     100  50   0    4s  6s country  start_year  end_year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      62 non-null     object
#  1   Duration    62 non-null     int64
#  2   Mat         62 non-null     int64
#  3   Inns        62 non-null     int64
#  4   NO          62 non-null     int64
#  5   Runs        62 non-null     int64
#  6   HS          62 non-null     object
#  7   Ave         62 non-null     float64
#  8   BF          62 non-null     object
#  9   SR          62 non-null     object
#  10  100         62 non-null     int64
#  11  50          62 non-null     int64
#  12  0           62 non-null     object
#  13  4s          62 non-null     int64
#  14  6s          62 non-null     int64
#  15  country     62 non-null     object
#  16  start_year  62 non-null     int64
#  17  end_year    62 non-null     int64
# dtypes: float64(1), int64(11), object(6)
# ...

# %%
#df["HS"]=df["HS"].str.split(pat="*").str[0]
#df["BF"]=df["BF"].str.split(pat="+").str[0]
#df["SR"]
#df["0"]
# Out:
# 0      7
# 1      -
# 2      2
# 3      1
# 4      2
#       ..
# 57     4
# 58    11
# 59     1
# 60     4
# 61     2
# Name: 0, Length: 62, dtype: object

# %%
df["HS"]=df["HS"].astype(int)

# %%
df["BF"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df["BF"].astype(int)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# ...

# %%
df[df["BF"]=="-"]
# Out:
#              Player  Duration  Mat  Inns  NO  Runs   HS    Ave BF SR  100  50  \
# 8        ED Weekes         10   48    81   5  4455  207  58.61  -  -   15  19
# 15      CL Walcott         12   44    74   7  3798  220  56.68  -  -   15  14
# 54  Hon.FS Jackson         12   20    33   4  1415  144  48.79  -  -    5   6
#
#     0   4s  6s country  start_year  end_year
# 8   6  258   2      WI        1948      1958
# 15  1  107  11      WI        1948      1960
# 54  3   51   0     ENG        1893      1905

# %%
df["BF"]=df["BF"].replace("-",0)

# %%
df[df["BF"]==0]
# Out:
#              Player  Duration  Mat  Inns  NO  Runs   HS    Ave BF SR  100  50  \
# 8        ED Weekes         10   48    81   5  4455  207  58.61  0  -   15  19
# 15      CL Walcott         12   44    74   7  3798  220  56.68  0  -   15  14
# 54  Hon.FS Jackson         12   20    33   4  1415  144  48.79  0  -    5   6
#
#     0   4s  6s country  start_year  end_year
# 8   6  258   2      WI        1948      1958
# 15  1  107  11      WI        1948      1960
# 54  3   51   0     ENG        1893      1905

# %%
df["SR"]=df["SR"].replace("-",0)

# %%
df[df["BF"]==0]
# Out:
#              Player  Duration  Mat  Inns  NO  Runs   HS    Ave BF SR  100  50  \
# 8        ED Weekes         10   48    81   5  4455  207  58.61  0  0   15  19
# 15      CL Walcott         12   44    74   7  3798  220  56.68  0  0   15  14
# 54  Hon.FS Jackson         12   20    33   4  1415  144  48.79  0  0    5   6
#
#     0   4s  6s country  start_year  end_year
# 8   6  258   2      WI        1948      1958
# 15  1  107  11      WI        1948      1960
# 54  3   51   0     ENG        1893      1905

# %%
df["BF"]=df["BF"].astype(int)

# %%
df["SR"]=df["SR"].astype(float)

# %%
df["0"]=df["0"].replace("-",0)

# %%
df["0"]=df["0"].astype(int)

# %%
df
# Out:
#           Player  Duration  Mat  Inns  NO  Runs   HS    Ave     BF     SR  \
# 0    DG Bradman         20   52    80  10  6996  334  99.94   9800  58.60
# 1   PHKD Mendis          3   12    21   2  1184  182  62.31   1839  64.38
# 2      AC Voges          1   20    31   7  1485  269  61.87   2667  55.68
# 3    RG Pollock          7   23    41   4  2256  274  60.97   1707  54.48
# 4    GA Headley         24   22    40   4  2190  270  60.83    416  56.00
# ..           ...       ...  ...   ...  ..   ...  ...    ...    ...    ...
# 57   KD Walters         16   74   125  14  5357  250  48.26   8662  49.16
# 58     GC Smith         12  117   205  13  9265  277  48.25  15525  59.67
# 59  WH Ponsford         10   29    48   4  2122  266  48.22   3118  44.77
# 60    SJ McCabe          8   39    62   5  2748  232  48.21   3217  60.02
# 61   DR Jardine          6   22    33   6  1296  127  48.00   2110  25.59
#
#     100  50   0    4s  6s country  start_year  end_year
# ...
