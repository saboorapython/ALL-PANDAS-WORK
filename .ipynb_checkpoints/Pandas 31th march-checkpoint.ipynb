# %%
#pandas! - Another phase of Python for Data Manipulation!

# %%
#!pip install pandas

# %%
import pandas as pd

# %%
#to importing dataset 

#pd.read_excel() #if we have excel file
#pd.read_csv() #if we have csv

# %%
df=pd.read_csv("supermarket_sales - supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#Data Understanding

# %%
#for Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df["Invoice ID"]
# Out:
# 0      750-67-8428
# 1      226-31-3081
# 2      631-41-3108
# 3      123-19-1176
# 4      373-73-7910
#           ...
# 995    233-67-5758
# 996    303-96-2227
# 997    727-02-1313
# 998    347-56-2442
# 999    849-09-3807
# Name: Invoice ID, Length: 1000, dtype: object

# %%
df[["Invoice ID","Branch","City"]]
# Out:
#       Invoice ID Branch       City
# 0    750-67-8428      A     Yangon
# 1    226-31-3081      C  Naypyitaw
# 2    631-41-3108      A     Yangon
# 3    123-19-1176      A     Yangon
# 4    373-73-7910      A     Yangon
# ..           ...    ...        ...
# 995  233-67-5758      C  Naypyitaw
# 996  303-96-2227      B   Mandalay
# 997  727-02-1313      A     Yangon
# 998  347-56-2442      A     Yangon
# 999  849-09-3807      A     Yangon
#
# [1000 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.rename(columns={'Product line':"Product_line", 'Unit price':"Unit_price",'Tax 5%':"Tax", 'gross margin percentage':"gross_margin", 'gross income':"gross_income"},inplace=True)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross_margin', 'gross_income', 'Rating'],
#       dtype='object')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df["Product_line"].unique() #for unique elements and values
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df["Product_line"].nunique() #if required number of unique values
# Out:
# 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product_line   1000 non-null   object
#  6   Unit_price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Tax            1000 non-null   float64
#  9   Total          1000 non-null   float64
#  10  Date           1000 non-null   object
#  11  Time           1000 non-null   object
#  12  Payment        1000 non-null   object
#  13  cogs           1000 non-null   float64
#  14  gross_margin   1000 non-null   float64
#  15  gross_income   1000 non-null   float64
#  16  Rating         1000 non-null   float64
# ...

# %%
df.head(1050)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.sample(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product_line  \
# 476  485-30-8700      A     Yangon        Normal  Female    Sports and travel
# 989  430-53-4718      B   Mandalay        Member    Male    Health and beauty
# 535  583-41-4548      C  Naypyitaw        Normal    Male   Home and lifestyle
# 658  816-72-8853      A     Yangon        Member  Female    Sports and travel
# 987  552-44-5977      B   Mandalay        Member    Male    Health and beauty
# 244  376-02-8238      B   Mandalay        Normal    Male   Home and lifestyle
# 265  253-12-6086      A     Yangon        Member  Female    Sports and travel
# 612  789-23-8625      B   Mandalay        Member    Male  Fashion accessories
# 422  271-88-8734      C  Naypyitaw        Member  Female  Fashion accessories
# 926  321-49-7382      B   Mandalay        Member    Male    Sports and travel
#
#      Unit_price  Quantity      Tax      Total       Date   Time      Payment  \
# ...

# %%
df[df["Total"]<100]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 19   319-50-3348      B   Mandalay        Normal  Female
# 22   273-16-6619      B   Mandalay        Normal    Male
# ..           ...    ...        ...           ...     ...
# 986  764-44-8999      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product_line  Unit_price  Quantity     Tax    Total       Date  \
# 1    Electronic accessories       15.28         5  3.8200  80.2200   03-08-19
# 8         Health and beauty       36.26         2  3.6260  76.1460   01-10-19
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity      Tax     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   01-05-19
# 1  Electronic accessories       15.28         5   3.8200   80.2200   03-08-19
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   03-03-19
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   02-08-19
#
#     Time      Payment    cogs  gross_margin  gross_income  Rating
# 0  13:08      Ewallet  522.83      4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product_line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit_price  Quantity      Tax      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   03-02-19  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   02-09-19  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
#        cogs  gross_margin  gross_income  Rating
# ...

# %%
df[df['Branch']=="C"]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product_line  Unit_price  Quantity      Tax     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
df["Branch"]=df["Branch"].replace("C","Gulshan")

# %%
df["Branch"]=df["Branch"].replace("A","Johar")

# %%
df["Branch"]=df["Branch"].replace("B","Koragi")

# %%
df["Branch"].unique()
# Out:
# array(['Johar', 'Gulshan', 'Koragi'], dtype=object)

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df["City"]=df["City"].replace('Yangon',"Karachi")

# %%
df["City"]=df["City"].replace('Naypyitaw',"Islamabad")

# %%
df["City"]=df["City"].replace('Mandalay',"Lahore")

# %%
df
# Out:
#       Invoice ID   Branch       City Customer type  Gender  \
# 0    750-67-8428    Johar    Karachi        Member  Female
# 1    226-31-3081  Gulshan  Islamabad        Normal  Female
# 2    631-41-3108    Johar    Karachi        Normal    Male
# 3    123-19-1176    Johar    Karachi        Member    Male
# 4    373-73-7910    Johar    Karachi        Normal    Male
# ..           ...      ...        ...           ...     ...
# 995  233-67-5758  Gulshan  Islamabad        Normal    Male
# 996  303-96-2227   Koragi     Lahore        Normal  Female
# 997  727-02-1313    Johar    Karachi        Member    Male
# 998  347-56-2442    Johar    Karachi        Normal    Male
# 999  849-09-3807    Johar    Karachi        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#for i in df.columns:     #this is to fetch column names
    print(i)
var=input("in which column you want to find nd replace:")
for i in df[var].unique():
    print(i)

select=input("what do you want?:\n1.Replace key word with any other? \n2. find specific keywords count")
if select=="1":
    old=input("write a key word you want to update:")
    new=input("write a new key word you want to replace with:")
    df[var]=df[var].replace(old,new)
    print(f"Dataframe and specific {var} column has been update with {new}")
    
#elif select=="2":
    #keyword=input("write a key word you want to count:")
    #print(f"df[var]==keyword.unique()}
    
#df
# Out:
#   Cell In[35], line 2
#     print(i)
#     ^
# IndentationError: unexpected indent

# %%
df
# Out:
#       Invoice ID   Branch       City Customer type  Gender  \
# 0    750-67-8428    Johar    Karachi        Member  Female
# 1    226-31-3081  Gulshan  Islamabad        Normal  Female
# 2    631-41-3108    Johar    Karachi        Normal    Male
# 3    123-19-1176    Johar    Karachi        Member    Male
# 4    373-73-7910    Johar    Karachi        Normal    Male
# ..           ...      ...        ...           ...     ...
# 995  233-67-5758  Gulshan  Islamabad        Normal    Male
# 996  303-96-2227   Koragi     Lahore        Normal  Female
# 997  727-02-1313    Johar    Karachi        Member    Male
# 998  347-56-2442    Johar    Karachi        Normal    Male
# 999  849-09-3807    Johar    Karachi        Member  Female
#
#                Product_line  Unit_price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
gendervssales=df.groupby("Gender")["Total"].sum().reset_index()

# %%
gendervssales[gendervssales["Gender"]=="Female"]
# Out:
#    Gender       Total
# 0  Female  167882.925

# %%
gendervssales.iloc[1]
# Out:
# Gender          Male
# Total     155083.824
# Name: 1, dtype: object

# %%
gendervssales.plot(kind="bar",x="Gender",y="Total")
# Out:
# <Axes: xlabel='Gender'>

# %%
gendervssales.plot(kind="pie",x="Gender",y="Total")
# Out:
# <Axes: ylabel='Total'>

# %%
gendervssales.plot(kind="line",x="Gender",y="Total")
# Out:
# <Axes: xlabel='Gender'>

# %%
gendervssales.plot(kind="",x="Gender",y="Total")

# %%
# !pip install matplotlib  #
